# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
geyser = sns.load_dataset('geyser')

# %%
geyser
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %%
geyser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   duration  272 non-null    float64
#  1   waiting   272 non-null    int64
#  2   kind      272 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.5+ KB

# %%
geyser.describe(include='all')
# Out:
#           duration     waiting  kind
# count   272.000000  272.000000   272
# unique         NaN         NaN     2
# top            NaN         NaN  long
# freq           NaN         NaN   172
# mean      3.487783   70.897059   NaN
# std       1.141371   13.594974   NaN
# min       1.600000   43.000000   NaN
# 25%       2.162750   58.000000   NaN
# 50%       4.000000   76.000000   NaN
# 75%       4.454250   82.000000   NaN
# max       5.100000   96.000000   NaN

# %% [markdown]
# ## Q. What duration is threshold above which we can call it long or short?

# %% [markdown]
# #### Let's find minimum of 'long' kind

# %%
long_min_dur = geyser[geyser['kind'] == 'long']['duration'].min()
long_min_dur
# Out:
# 2.383

# %% [markdown]
# #### Let's find maximum of 'short' kind

# %%
short_max_dur = geyser[geyser['kind'] == 'short']['duration'].max()
short_max_dur
# Out:
# 3.833

# %%
# Set the figure size
plt.figure(figsize=(20, 10))

# First subplot
ax1 = plt.subplot(2, 1, 1)
sns.boxplot(x='duration', data=geyser[geyser['kind'] == 'long'], ax=ax1)
plt.title('Long kind duration')

# Second subplot
ax2 = plt.subplot(2, 1, 2, sharex=ax1)
sns.boxplot(x='duration', data=geyser[geyser['kind'] == 'short'], ax=ax2)
plt.title('Short kind duration')

# Show the plot
plt.show()

# %% [markdown]
# ### Thus, threshold can be any value between 2.5 to 4.0 aprroximately.

# %% [markdown]
# ### Further EDA

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,1,1)
sns.boxplot(x= 'waiting', data = geyser)

plt.subplot(2,1,2)
sns.histplot(x= 'waiting', data = geyser)

plt.show()

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,1,1)
sns.boxplot(x= 'duration', data = geyser)

plt.subplot(2,1,2)
sns.histplot(x= 'duration', data = geyser)

plt.show()

# %% [markdown]
# ### Hence, distribution for both the parameters is bimodal. Which is obvious owing to two modes - short eruption and long eruption. With median skewed towards long mode, due to more occurance and more value for parameters

# %% [markdown]
# ## Let's compare for each mode

# %% [markdown]
# ### a) Duration

# %%
# Set the figure size
plt.figure(figsize=(10, 20))


# First subplot
ax1 = plt.subplot(4, 1, 1)
sns.boxplot(x='duration', data=geyser[geyser['kind'] == 'long'], ax=ax1)
plt.title('Box plot of Long kind duration')

# First subplot
ax2 = plt.subplot(4, 1, 2, sharex = ax1)
sns.histplot(x='duration', data=geyser[geyser['kind'] == 'long'], ax=ax2)
plt.title('Histogram of Long kind duration')

# Second subplot
ax3 = plt.subplot(4, 1, 3, sharex=ax1)
sns.boxplot(x='duration', data=geyser[geyser['kind'] == 'short'], ax=ax3)
plt.title('Box plot of Short kind duration')

# Second subplot
ax4 = plt.subplot(4, 1, 4, sharex=ax1)
sns.histplot(x='duration', data=geyser[geyser['kind'] == 'short'], ax=ax4)
plt.title('Histogram of Short kind duration')

# Show the plot
plt.show()

# %% [markdown]
# ### b) Waiting

# %%
# Set the figure size
plt.figure(figsize=(10, 20))

# First subplot
ax1 = plt.subplot(4, 1, 1)
sns.boxplot(x='waiting', data=geyser[geyser['kind'] == 'long'], ax=ax1)
plt.title('Box plot of Long kind duration')

# First subplot
ax2 = plt.subplot(4, 1, 2, sharex = ax1)
sns.histplot(x='waiting', data=geyser[geyser['kind'] == 'long'], ax=ax2)
plt.title('Histogram of Long kind duration')

# Second subplot
ax3 = plt.subplot(4, 1, 3, sharex=ax1)
sns.boxplot(x='waiting', data=geyser[geyser['kind'] == 'short'], ax=ax3)
plt.title('Box plot of Short kind duration')

# Second subplot
ax4 = plt.subplot(4, 1, 4, sharex=ax1)
sns.histplot(x='waiting', data=geyser[geyser['kind'] == 'short'], ax=ax4)
plt.title('Histogram of Short kind duration')

# Show the plot
plt.show()
